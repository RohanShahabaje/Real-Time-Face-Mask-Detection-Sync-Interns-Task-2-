# %%
# FACE MASK DETECTION TASK 3 SYNC INTERNS [ROHAN SHAHABAJE]

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\ROHAN SHAHABAJE\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import cv2

# %%
img = cv2.imread('D:\FACE MASK DETECTION\img_1.jpg')
print(img.shape) 
# height, width, color channel(RGB)

print(img[0])
#Pixels at the 1st array
# Out:
# (628, 1198, 3)
# [[ 56  69  85]
#  [ 56  69  85]
#  [ 57  67  84]
#  ...
#  [ 57 100 133]
#  [ 66 109 142]
#  [ 67 110 143]]

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\ROHAN SHAHABAJE\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
while True:
    cv2.imshow('result',img)
    if cv2.waitKey(2) == 27: # Here the 27 is the ASCII number of the Escape key so my window will terminate if i press esc
        break
cv2.destroyAllWindows()
